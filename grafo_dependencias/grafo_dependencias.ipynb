# %% [markdown]
# ### NetworkX e Gephi
# Use o código abaixo em conjunto com o Gephi:
# 1. carregue o exemplo Les Miserables.gexf no Gephi
# 2. exporte no formato GML (miserables.gml) para carregar no notebook
#
# Esta rede representa as interações dos personagens do romance de Victor Hugo.\
# Compare alguns valores fornecidos pelo NetworkX com os disponíveis no Gephi

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()

# disciplinas 
with open("disciplinas.txt") as file:
    for line in file:
        G.add_node(line.rstrip())
G.nodes()
# Out:
# NodeView(('Init', 'CSF13', 'CSD20', 'MA71A', 'FI71S', 'MA71B', 'EEX11', 'CSF20', 'CSE20', 'MA72A', 'FI72S', 'FI72N', 'QB70C', 'EEX21', 'CSF30', 'MA70H', 'MA73A', 'FI73S', 'EEB21', 'MA70G', 'CSD21', 'EEB22', 'EEB31', 'EEF11', 'EEQ31', 'FI74N', 'FI74S', 'CSA30', 'CSB30', 'CSG20', 'CSR31', 'CSW30', 'EEE31', 'EEF21', 'ES70G', 'CSA31', 'CSE30', 'CSO30', 'CSW40', 'EEE32', 'EEX22', 'CSI30', 'CSR30', 'CSW41', 'CSW42', 'EEC21', 'EEQ32', 'ES70P', 'EEC31', 'EEX23', 'GE70D', 'CSX42', 'GE70H', 'QB70E', 'CSX43', 'EEF31', 'CSA40', 'CSA41', 'CSA42', 'CSA43', 'CSA44', 'CSA45', 'CSB40', 'CSB41', 'CSB42', 'CSB43', 'CSB50', 'CSB51', 'CSB52', 'CSB53', 'CSB54', 'CSB55', 'CSD40', 'CSD41', 'CSD42', 'CSD43', 'CSD45', 'CSD47', 'CSD52', 'CSD55', 'CSD57', 'CSD58', 'CSE40', 'CSE41', 'CSE42', 'CSE43', 'CSE44', 'CSE45', 'CSE46', 'CSE47', 'CSE48', 'CSG41', 'CSG42', 'CSG43', 'CSG44', 'CSG45', 'CSG47', 'CSG48', 'CSG70', 'CSH30', 'CSH41', 'CSH42', 'CSH43', 'CSH44', 'CSH45', 'CSH50', 'CSH51', 'CSI31', 'CSI41', 'CSI42', 'CSI51', 'CSI52', 'CSI53', 'CSI54', 'CSI55', 'CSI56', 'CSI57', 'CSI58', 'CSL40', 'CSL41', 'CSM30', 'CSM40', 'CSM41', 'CSM42', 'CSM43', 'CSM44', 'CSM45', 'CSR20', 'CSR40', 'CSR41', 'CSR42', 'CSR43', 'CSR44', 'CSR45', 'CSR46', 'CSR47', 'CSR48', 'CSR53', 'CSU40', 'CSU41', 'CSU42', 'CSU43', 'CSU44', 'CSV30', 'CSV40', 'CSV41', 'CSV42', 'CSV43', 'CSV45', 'CSV50', 'CSV52', 'CSV53', 'CSW43', 'CSW44', 'CSW45', 'CSW46', 'CSW47', 'CSW48', 'CSW49', 'CSW55', 'CSW56', 'DI84D', 'ED70T', 'ED70U', 'EEC41', 'EEC42', 'EEC43', 'EEC44', 'EEC45', 'EEC46', 'EEL51', 'EES41', 'EEY41', 'EEY42', 'EEY43', 'EEY44', 'EEY51', 'EEY52', 'ELH03', 'ELSC01', 'ELSP01', 'EL6AE', 'EL6BA', 'EL6BB', 'EL6BC', 'EL6BD', 'EL6BE', 'EL6CA', 'EL6CB', 'EL6CC', 'EL6CD', 'EL6EE', 'EL64B', 'EL65B', 'EL65F', 'EL66B', 'EL75H', 'ES70B', 'ES70J', 'ES70N', 'ET7GL', 'ET7GM', 'FCH7FC', 'FCH7GA', 'FCH7HB', 'FCH7HC', 'FCH7SC', 'FCH7XF', 'FCH7XG', 'FI70A', 'FI70B', 'FI70D', 'FI70E', 'FI77B', 'GE70F', 'ICSB55', 'IF6BV', 'IF6CJ', 'IF6CK', 'IF6CM', 'LEM701', 'LEM702', 'LEM703', 'MA7AV', 'MA70C', 'QB7AH', 'QB7AI', 'QB70F', 'QB74I'))

# %%
print(G.number_of_nodes())
# Out:
# 229

# %%
# todas as dependencias entre disciplinas
with open("dependencias.txt") as file:
    for line in file:
        G.add_edge(line.rstrip().split(";")[0], line.rstrip().split(";")[1])
G.edges()
# Out:
# EdgeView([('Init', 'CSF13'), ('Init', 'CSD20'), ('Init', 'MA71A'), ('Init', 'FI71S'), ('Init', 'MA71S'), ('CSF13', 'CSF20'), ('CSF13', 'CSE20'), ('CSF13', 'MA70C'), ('CSD20', 'CSD21'), ('MA71A', 'MA72A'), ('MA71A', 'FI72S'), ('MA71A', 'FI72N'), ('FI71S', 'FI72S'), ('FI71S', 'FI72N'), ('FI71S', 'FI70A'), ('MA71B', 'MA70G'), ('MA71B', 'CSA44'), ('MA71B', 'CSA45'), ('MA71B', 'CSV30'), ('MA71B', 'FI70A'), ('MA71B', 'MA70C'), ('EEX11', 'EEX21'), ('EEX11', 'EEF21'), ('CSF20', 'CSF30'), ('CSF20', 'CSW30'), ('CSE20', 'CSB30'), ('CSE20', 'CSG20'), ('CSE20', 'CSH30'), ('CSE20', 'CSM41'), ('CSE20', 'CSM43'), ('CSE20', 'IF6CJ'), ('MA72A', 'MA70H'), ('MA72A', 'MA73A'), ('MA72A', 'FI73S'), ('MA72A', 'EEB21'), ('MA72A', 'MA70G'), ('MA72A', 'MA70C'), ('FI72S', 'FI73S'), ('FI72S', 'EEB21'), ('FI72S', 'FI70D'), ('CSF30', 'CSA30'), ('CSF30', 'CSB30'), ('CSF30', 'CSD42'), ('CSF30', 'CSV30'), ('CSF30', 'CSW45'), ('MA70H', 'CSB53'), ('MA70H', 'CSB54'), ('MA70H', 'CSD40'), ('MA70H', 'CSD43'), ('MA70H', 'CSD45'), ('MA70H', 'CSD55'), ('MA70H', 'CSD58'), ('MA70H', 'CSI58'), ('MA70H', 'EL6CA'), ('MA70H', 'EL6CD'), ('MA73A', 'EEQ31'), ('MA73A', 'FI74N'), ('MA73A', 'FI74S'), ('MA73A', 'EEE32'), ('MA73A', 'EL64B'), ('FI73S', 
CSR41'), ('CSR30', 'CSR42'), ('CSR30', 'CSR43'), ('CSR30', 'CSR44'), ('CSR30', 'CSR45'), ('CSR30', 'CSR46'), ('CSR30', 'CSR47'), ('CSR30', 'CSR48'), ('CSR30', 'CSR53'), ('CSR30', 'EL6BC'), ('CSR30', 'EL6BD'), ('CSR30', 'EL6BE'), ('CSR30', 'IF6CK'), ('CSW41', 'CSW55'), ('EEC21', 'EEC31'), ('EEC21', 'EEY41'), ('EEC21', 'EEY52'), ('EEC21', 'EL6AE'), ('EEC21', 'EL65F'), ('EEQ32', 'CSW48'), ('ES70P', 'ES70B'), ('EEC31', 'EEC41'), ('EEC31', 'EEC42'), ('EEC31', 'EEC43'), ('EEC31', 'EEC44'), ('EEC31', 'EEC45'), ('EEC31', 'EEC46'), ('EEX23', 'CSX42'), ('CSX42', 'CSX43'), ('CSE40', 'CSE41'), ('CSE40', 'CSE42'), ('CSE40', 'CSE43'), ('CSE40', 'CSE44'), ('CSE40', 'CSE45'), ('CSE40', 'CSE46'), ('CSE40', 'CSE47'), ('CSE40', 'CSE48'), ('CSH30', 'CSH41'), ('CSH30', 'CSH42'), ('CSH30', 'CSH43'), ('CSH30', 'CSH45'), ('CSH30', 'CSH50'), ('CSH30', 'CSH5 ...

# %%
print(G.number_of_edges())
# Out:
# 218

# %%
nx.draw(G, with_labels=True, arrows=True, node_size=20, font_size=2)

# %%
G.degree()
# Out:
# DegreeView({'Init': 5, 'CSF13': 4, 'CSD20': 2, 'MA71A': 4, 'FI71S': 4, 'MA71B': 6, 'EEX11': 2, 'CSF20': 3, 'CSE20': 7, 'MA72A': 7, 'FI72S': 5, 'FI72N': 2, 'QB70C': 0, 'EEX21': 1, 'CSF30': 6, 'MA70H': 11, 'MA73A': 6, 'FI73S': 8, 'EEB21': 4, 'MA70G': 3, 'CSD21': 5, 'EEB22': 4, 'EEB31': 4, 'EEF11': 1, 'EEQ31': 5, 'FI74N': 2, 'FI74S': 2, 'CSA30': 7, 'CSB30': 15, 'CSG20': 9, 'CSR31': 5, 'CSW30': 5, 'EEE31': 3, 'EEF21': 2, 'ES70G': 3, 'CSA31': 9, 'CSE30': 3, 'CSO30': 4, 'CSW40': 5, 'EEE32': 7, 'EEX22': 1, 'CSI30': 13, 'CSR30': 18, 'CSW41': 2, 'CSW42': 1, 'EEC21': 7, 'EEQ32': 2, 'ES70P': 2, 'EEC31': 7, 'EEX23': 2, 'GE70D': 0, 'CSX42': 2, 'GE70H': 0, 'QB70E': 0, 'CSX43': 1, 'EEF31': 0, 'CSA40': 1, 'CSA41': 1, 'CSA42': 1, 'CSA43': 1, 'CSA44': 2, 'CSA45': 2, 'CSB40': 1, 'CSB41': 1, 'CSB42': 1, 'CSB43': 1, 'CSB50': 1, 'CSB51': 1, 'CSB52': 1, 'CSB53': 2, 'CSB54': 2, 'CSB55': 0, 'CSD40': 1, 'CSD41': 1,
# %%
dicDegree = dict(G.degree() )
valores = sorted(set(dicDegree.values()))
valores

hist = [list(dicDegree.values()).count(x) for x in valores]

plt.plot(valores, hist, 'ro-') 

plt.xlabel('Grau')
plt.ylabel('Numero de nós')
# Out:
# Text(0, 0.5, 'Numero de nós')

# %%
deg=dict(G.degree())
soma = 0
for i in deg.values():
    soma += i
aver = soma/len(deg)
print(aver)
print(nx.average_clustering(G))
print(nx.average_clustering(G, count_zeros=False))
print(nx.diameter(G))
#print(nx.clustering(G))
clus=dict(nx.clustering(G))

# Gephi: average clustering coefficient for nodes with degree > 1 ()
soma = 0
c = 0
for i in range(len(deg)):
    if list(deg.values())[i] > 1:
     soma += list(clus.values())[i]
     c +=1
clus_aver = soma/c;
print(clus_aver)
# Out:
# 1.8956521739130434
# 0.015110420979986198
# 0.49648526077097505
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# c:\Users\cesar\TCC\grafo_dependencias\grafo_dependencias.ipynb Cell 9 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/cesar/TCC/grafo_dependencias/grafo_dependencias.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> print(nx.average_clustering(G))
#       <a href='vscode-notebook-cell:/c%3A/Users/cesar/TCC/grafo_dependencias/grafo_dependencias.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> print(nx.average_clustering(G, count_zeros=False))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cesar/TCC/grafo_dependencias/grafo_dependencias.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> print(nx.diameter(G))
#      <a href='vscode-notebook-cell:/c%3A/Users/cesar/TCC/grafo_dependencias/grafo_dependencias.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a> #print(nx.clustering(G))
#      <a href='vscode-notebook-cell:/c%3A/Users/cesar/TCC/grafo_dependencias/grafo_dependencias.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a> clus=dict(nx.clustering(G))
#
# File c:\Users\cesar\AppData\Local\Programs\Python\Python310\lib\site-packages\networkx\algorithms\distance_measures.py:377, in diameter(G, e, usebounds, weight)
#     375     return _extrema_bounding(G, compute="diameter", weight=weight)
#     376 if e is None:
# --> 377     e = eccentricity(G, weight=weight)
#     378 return max(e.values())
#
# File c:\Users\cesar\AppData\Local\Programs\Python\Python310\lib\site-packages\networkx\algorithms\distance_measures.py:317, in eccentricity(G, v, sp, weight)
#     315         else:
#     316             msg = "Found infinite path length because the graph is not" " connected"
# --> 317         raise nx.NetworkXError(msg)
#     319     e[n] = max(length.values())
#     321 if v in G:
#
# NetworkXError: Found infinite path length because the graph is not connected
