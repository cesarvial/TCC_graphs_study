# %%
import pandas as pd

teste = pd.read_csv('output/desc_cliquesmax_1.txt')
teste.head()
# Out:
#   Unnamed: 0     ID_ANONIMO  PRECISION     RECALL  PRECISION_OB  RECALL_OB  \
# 0      count      62.000000  62.000000  62.000000     62.000000  62.000000
# 1       mean  167358.951613   0.541366   0.734954      0.952174   0.840694
# 2        std   24047.071681   0.138206   0.207024      0.127128   0.110601
# 3        min   90729.000000   0.125000   0.076923      0.142857   0.500000
# 4        25%  152208.500000   0.440625   0.606250      1.000000   0.775510
#
#    PRECISION_OP  RECALL_OP
# 0     62.000000  62.000000
# 1      0.277688   0.117426
# 2      0.253373   0.094912
# 3      0.000000   0.000000
# 4      0.041667   0.015625

# %%
import matplotlib.pyplot as plt

ps = []
rs = []

ps_ob = []
rs_ob = []

ps_op = []
rs_op = []
for i in range(1,8):
    teste = pd.read_csv(f'output/desc_cliquesmax_{i}.txt')
    ps.append(teste['PRECISION'][1])
    rs.append(teste['RECALL'][1])
    ps_ob.append(teste['PRECISION_OB'][1])
    rs_ob.append(teste['RECALL_OB'][1])
    ps_op.append(teste['PRECISION_OP'][1])
    rs_op.append(teste['RECALL_OP'][1])

    print(f"{i} - P: {teste['PRECISION'][1]}")
    print(f"R: {teste['RECALL'][1]}")

fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs, ps, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Cliquesmax')
plt.savefig('output/graficos/cliquesmax.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs_ob, ps_ob, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Cliquesmax Obrigatorias')
plt.savefig('output/graficos/cliquesmax_ob.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs_op, ps_op,  c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Cliquesmax Optativas')
plt.savefig('output/graficos/cliquesmax_opt.png')
plt.show()
# Out:
# 1 - P: 0.5413655839896501
# R: 0.734953900629089
# 2 - P: 0.4407639277091242
# R: 0.6203744138301963
# 3 - P: 0.3709910280941758
# R: 0.5325177883701393
# 4 - P: 0.2422841268208915
# R: 0.4465231092436975
# 5 - P: 0.2019221858826321
# R: 0.3633552271483306
# 6 - P: 0.1104580793356303
# R: 0.2034175574991901
# 7 - P: 0.0479031385281385
# R: 0.109375

# %%
ps = []
rs = []

ps_ob = []
rs_ob = []

ps_op = []
rs_op = []
for i in range(1,8):
    teste = pd.read_csv(f'output/desc_comunidades_{i}.txt')
    ps.append(teste['PRECISION'][1])
    rs.append(teste['RECALL'][1])
    ps_ob.append(teste['PRECISION_OB'][1])
    rs_ob.append(teste['RECALL_OB'][1])
    ps_op.append(teste['PRECISION_OP'][1])
    rs_op.append(teste['RECALL_OP'][1])

    print(f"{i} - P: {teste['PRECISION'][1]}")
    print(f"R: {teste['RECALL'][1]}")

fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs, ps, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Comunidades')
plt.savefig('output/graficos/comunidades.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs_ob, ps_ob, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Comunidades Obrigatorias')
plt.savefig('output/graficos/comunidades_ob.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs_op, ps_op, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Comunidades Optativas')
plt.savefig('output/graficos/comunidades_opt.png')
plt.show()
# Out:
# 1 - P: 0.5291442767964532
# R: 0.7316233207788558
# 2 - P: 0.4360652541885032
# R: 0.610718570726932
# 3 - P: 0.3590016102094975
# R: 0.5062267901290133
# 4 - P: 0.2231522679390326
# R: 0.3988095238095238
# 5 - P: 0.194328945789392
# R: 0.3444786535303777
# 6 - P: 0.0924220337485643
# R: 0.1622610949141561
# 7 - P: 0.0418425324675324
# R: 0.09375

# %%
ps = []
rs = []

ps_ob = []
rs_ob = []

ps_op = []
rs_op = []
for i in range(1,8):
    teste = pd.read_csv(f'output/desc_kcliques_{i}.txt')
    ps.append(teste['PRECISION'][1])
    rs.append(teste['RECALL'][1])
    ps_ob.append(teste['PRECISION_OB'][1])
    rs_ob.append(teste['RECALL_OB'][1])
    ps_op.append(teste['PRECISION_OP'][1])
    rs_op.append(teste['RECALL_OP'][1])

    print(f"{i} - P: {teste['PRECISION'][1]}")
    print(f"R: {teste['RECALL'][1]}")

fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs, ps, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall KCliques')
plt.savefig('output/graficos/kcliques.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs_ob, ps_ob, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall KCliques Obrigatorias')
plt.savefig('output/graficos/kcliques_ob.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs_op, ps_op, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall KCliques Optativas')
plt.savefig('output/graficos/kcliques_opt.png')
plt.show()
# Out:
# 1 - P: 0.5139902322955134
# R: 0.7067054836505805
# 2 - P: 0.4259175437765972
# R: 0.6011696779749449
# 3 - P: 0.3562739407494819
# R: 0.5114866726499558
# 4 - P: 0.2343113650491946
# R: 0.4255199781061849
# 5 - P: 0.2094692995655562
# R: 0.3747186147186148
# 6 - P: 0.1102084509693205
# R: 0.1985679779158039
# 7 - P: 0.051096681096681
# R: 0.1166666666666666

# %%
ps = []
rs = []

ps_ob = []
rs_ob = []

ps_op = []
rs_op = []
for i in range(1,8):
    teste = pd.read_csv(f'output/desc_cosseno_{i}.txt')
    ps.append(teste['PRECISION'][1])
    rs.append(teste['RECALL'][1])
    ps_ob.append(teste['PRECISION_OB'][1])
    rs_ob.append(teste['RECALL_OB'][1])
    ps_op.append(teste['PRECISION_OP'][1])
    rs_op.append(teste['RECALL_OP'][1])

    print(f"{i} - P: {teste['PRECISION'][1]}")
    print(f"R: {teste['RECALL'][1]}")

fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs, ps, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.ylabel('Recall')
plt.xlabel('Precision')
plt.title('Precision-Recall Dist. Cossenos')
plt.savefig('output/graficos/cossenos.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs_ob, ps_ob, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.ylabel('Recall')
plt.xlabel('Precision')
plt.title('Precision-Recall Dist. Cossenos Obrigatorias')
plt.savefig('output/graficos/cossenos_ob.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter(rs_op, ps_op, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.ylabel('Recall')
plt.xlabel('Precision')
plt.title('Precision-Recall Dist. Cossenos Optativas')
plt.savefig('output/graficos/cossenos_opt.png')
plt.show()
# Out:
# 1 - P: 0.5251829019591029
# R: 0.7144659566719207
# 2 - P: 0.4431608033085218
# R: 0.6110065184773166
# 3 - P: 0.3869564429772595
# R: 0.5449779070642147
# 4 - P: 0.2633172438461812
# R: 0.4611452466291176
# 5 - P: 0.2139977265450844
# R: 0.3838512241054614
# 6 - P: 0.1148312571781959
# R: 0.2117751862649821
# 7 - P: 0.0479031385281385
# R: 0.109375

# %%
ps = []
rs = []

ps_ob = []
rs_ob = []

ps_op = []
rs_op = []
for i in range(1,8):
    teste = pd.read_csv(f'output/desc_notnull_cliquesmax_{i}.txt')
    ps.append(teste['PRECISION'][1])
    rs.append(teste['RECALL'][1])
    ps_ob.append(teste['PRECISION_OB'][1])
    rs_ob.append(teste['RECALL_OB'][1])
    ps_op.append(teste['PRECISION_OP'][1])
    rs_op.append(teste['RECALL_OP'][1])

    print(f"{i} - P: {teste['PRECISION'][1]}")
    print(f"R: {teste['RECALL'][1]}")

fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs, ps,c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Cliquesmax notnull')
plt.savefig('output/graficos/cliquesmax_notnull.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs_ob, ps_ob,c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Cliquesmax notnull obrig')
plt.savefig('output/graficos/cliquesmax_notnull_ob.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs_op, ps_op,c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Cliquesmax notnull opt')
plt.savefig('output/graficos/cliquesmax_notnull_opt.png')
plt.show()
# Out:
# 1 - P: 0.5833998779952637
# R: 0.8023734558378403
# 2 - P: 0.5104060966402164
# R: 0.7383412907543342
# 3 - P: 0.4832730350597386
# R: 0.7292401942169745
# 4 - P: 0.4101475571212413
# R: 0.8337092731829575
# 5 - P: 0.4083202655929929
# R: 0.8757575757575757
# 6 - P: 0.303116883116883
# R: 0.7166666666666667
# 7 - P: 0.2363636363636363
# R: 0.625

# %%
ps = []
rs = []

ps_ob = []
rs_ob = []

ps_op = []
rs_op = []
for i in range(1,8):
    teste = pd.read_csv(f'output/desc_notnull_kcliques_{i}.txt')
    ps.append(teste['PRECISION'][1])
    rs.append(teste['RECALL'][1])
    ps_ob.append(teste['PRECISION_OB'][1])
    rs_ob.append(teste['RECALL_OB'][1])
    ps_op.append(teste['PRECISION_OP'][1])
    rs_op.append(teste['RECALL_OP'][1])

    print(teste['PRECISION'][1])

fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs,ps, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall kcliques notnull')
plt.savefig('output/graficos/kcliques_notnull.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs_ob,ps_ob, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall kcliques notnull obrig')
plt.savefig('output/graficos/kcliques_notnull_ob.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs_op,ps_op, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall kcliques notnull opt')
plt.savefig('output/graficos/kcliques_notnull_opt.png')
plt.show()
# Out:
# 0.5754264530790906
# 0.5636116837020789
# 0.5177393370224586
# 0.3223567608861726
# 0.3759618241235888
# 0.3242424242424242
# 0.2363636363636363

# %%
ps = []
rs = []

ps_ob = []
rs_ob = []

ps_op = []
rs_op = []
for i in range(1,8):
    teste = pd.read_csv(f'output/desc_notnull_comunidades_{i}.txt')
    ps.append(teste['PRECISION'][1])
    rs.append(teste['RECALL'][1])
    ps_ob.append(teste['PRECISION_OB'][1])
    rs_ob.append(teste['RECALL_OB'][1])
    ps_op.append(teste['PRECISION_OP'][1])
    rs_op.append(teste['RECALL_OP'][1])

    print(teste['PRECISION'][1])

fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs,ps, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall comunidades notnull')
plt.savefig('output/graficos/comunidades_notnull.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs_ob,ps_ob, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall comunidades notnull obrig')
plt.savefig('output/graficos/comunidades_notnull_ob.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs_op,ps_op, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall comunidades notnull opt')
plt.savefig('output/graficos/comunidades_notnull_opt.png')
plt.show()
# Out:
# 0.5532288396254288
# 0.5451420121973929
# 0.5390437706073835
# 0.3202380952380952
# 0.3411111111111111
# nan
# nan

# %%
ps = []
rs = []

ps_ob = []
rs_ob = []

ps_op = []
rs_op = []
for i in range(1,8):
    teste = pd.read_csv(f'output/desc_notnull_cosseno_{i}.txt')
    ps.append(teste['PRECISION'][1])
    rs.append(teste['RECALL'][1])
    ps_ob.append(teste['PRECISION_OB'][1])
    rs_ob.append(teste['RECALL_OB'][1])
    ps_op.append(teste['PRECISION_OP'][1])
    rs_op.append(teste['RECALL_OP'][1])

    print(teste['PRECISION'][1])

fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs,ps, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall cosseno notnull')
plt.savefig('output/graficos/cosseno_notnull.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs_ob,ps_ob, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall cosseno notnull obrig')
plt.savefig('output/graficos/cosseno_notnull_ob.png')
plt.show()
fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.scatter( rs_op,ps_op, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall cosseno notnull opt')
plt.savefig('output/graficos/cosseno_notnull_opt.png')
plt.show()
# Out:
# 0.5621934186026637
# 0.5373269345507641
# 0.5018271998601862
# 0.430221947333712
# 0.4138084178893002
# 0.3389610389610389
# 0.2363636363636363

# %%
ps_cliquesmax = []
rs_cliquesmax = []
ps_comunidades = []
rs_comunidades = []
ps_kcliques = []
rs_kcliques = []
ps_cossenos = []
rs_cossenos = []

for i in range(1,8):
    teste = pd.read_csv(f'output/desc_notnull_cliquesmax_{i}.txt')
    ps_cliquesmax.append(teste['PRECISION_OP'][1])
    rs_cliquesmax.append(teste['RECALL_OP'][1])
    teste = pd.read_csv(f'output/desc_notnull_kcliques_{i}.txt')
    ps_comunidades.append(teste['PRECISION_OP'][1])
    rs_comunidades.append(teste['RECALL_OP'][1])
    teste = pd.read_csv(f'output/desc_notnull_comunidades_{i}.txt')
    ps_kcliques.append(teste['PRECISION_OP'][1])
    rs_kcliques.append(teste['RECALL_OP'][1])
    teste = pd.read_csv(f'output/desc_notnull_cosseno_{i}.txt')
    ps_cossenos.append(teste['PRECISION_OP'][1])
    rs_cossenos.append(teste['RECALL_OP'][1])

fig, ax = plt.subplots()
ax.scatter( rs_cliquesmax,ps_cliquesmax, c=['#E6B0AA','#D98880','#CD6155','#C0392B','#A93226','#7B241C','#641E16'], label='cliquesmax')
ax.scatter( rs_comunidades,ps_comunidades, c=['#D7BDE2','#BB8FCE','#A569BD','#8E44AD','#7D3C98','#6C3483','#5B2C6F'], label='comunidades')
ax.scatter( rs_kcliques,ps_kcliques, c=['#AED6F1','#85C1E9','#5DADE2','#3498DB','#2E86C1','#2874A6','#21618C'], label='comunidades')
ax.scatter( rs_cossenos,ps_cossenos, c=['#A2D9CE','#73C6B6','#45B39D','#16A085','#138D75','#117A65','#0E6655'], label='comunidades')
ax.set_xlim([0,1])
ax.set_ylim([0,1])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall')
plt.show()
