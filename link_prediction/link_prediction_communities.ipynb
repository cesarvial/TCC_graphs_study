# %% [markdown]
# # Rodando Script do grafo de trilhas

# %%
# roda o script do grafo de trilhas, tendo todas as trilhas de cada estudante e as comunidades/cliques
# %run "../grafo_trilhas/grafo_trilhas.ipynb"
# Out:
# ../excel/dados_historicos_alunos_de_EngComputacaoCuritiba formados.csv
# ../excel/dados_historicos_alunos_de_EngComputacaoCuritiba regulares.csv
# 50026
# 484
# ['CSH30', 'CSV30', 'CSH42', 'CSI53', 'CSV40', 'CSR44', 'CSR41', 'CSR42', 'MA70C', 'CSB51', 'ED70T', 'CSB41', 'CSI41', 'DI84D', 'CSV45', 'CSR43', 'CSM44', 'CSM41', 'CSM43', 'ES70J', 'ES70B', 'CSM40', 'CSB53', 'ES70N', 'GE70F', 'CSA44', 'CSB54', 'CSH44', 'EEY41', 'ED70U', 'CSH43', 'CSE40', 'CSM30', 'CSI56', 'CSA45', 'FI70B', 'FI70D', 'CSA42', 'EL64B', 'CSV52', 'CSB52', 'CSD41', 'FI70A', 'CSD40', 'CSR53', 'CSG42', 'CSI58', 'CSI57', 'CSG48', 'CSV41', 'CSI51', 'CSW45', 'CSE43', 'CSI55', 'FCH7HB', 'CSR47', 'EEY44', 'CSH45', 'CSA41', 'EEC41', 'EL6CB', 'EEY43', 'CSR48', 'EEY42', 'EL6AE', 'CSH41', 'CSD52', 'EEY51', 'EEL51', 'CSI54', 'CSA43', 'CSW47', 'CSI31', 'IF6BV', 'CSR45', 'CSG44', 'FI70E', 'EL75H']
# 90729 []
# 113853 []
# 118844 []
# 123664 []
# 123676 []
# 123677 []
# 123686 []
# 123688 []
# 123736 []
# 129034 []
# 131006 []
# ...

# %% [markdown]
# # Pós processamento dos dados dos grafos de trilhas, para sua utilização futura

# %%
# as comunidades são listas de ids de alunos, logo é fácil buscar os alunos de cada comunidade
print(comunidades)
# busca o estudante pelo id
def get_student_by_id(id):
    for e in estudantes:
        if (e.id_anonimo == id):
            return e.id_anonimo, e.trilhas, e.disciplinas
# Out:
# [['90729', '113853', '123736', '129034', '150878', '151217', '158257', '159067', '160836', '160839', '160852', '160855', '161223', '161226', '165431', '165432', '165685', '165894', '166050', '171745', '171749', '172045', '172207', '172974', '179944', '11357', '110307', '118817', '126813', '147820', '160841', '160846', '177170', '190684', '193634', '198761', '212903', '250128', '250152', '251697', '253829', '253830'], ['118844', '123664', '150892', '156158', '161216', '165895', '172044', '172307', '175962', '179408', '179823', '190494', '191284', '198372', '198543', '104372', '136716', '136720', '160837', '161257', '169044', '171652', '172042', '175469', '177422', '177427', '179405', '186026', '186031'], ['123676', '123686', '123688', '131006', '131014', '136341', '136736', '145077', '150887', '171746', '171750', '171751', '171755', '172208', '179624', '179819', '179822', '182856', '183414', '186021', '186036', '190495', '190508', '190615', '202261', '137191', '166152', '171698', '172
# ...

# %%
# Define uma estrutura de comunidades que possui uma lista de ids (os alunos) e uma lista de trilhas (ordenada e com o número de estudantes)
comunidades_trilhas = []
for c in comunidades:
    comm = {"estudantes":[],
            "trilhas":[]}
    comm["estudantes"] = c
    em_trilha = []
    for trilha in trilhas:
        est_in_trilha = 0
        for e_id in range(len(c)-1):
            e_trilhas = get_student_by_id(c[e_id])[1]
            if (trilha[0] in e_trilhas):
                est_in_trilha += 1
        if (est_in_trilha > 0):
            em_trilha.append([trilha[0], est_in_trilha])
    comm["trilhas"] = sorted(em_trilha, key=lambda t: t[1], reverse=True)
    comunidades_trilhas.append(comm)
comunidades_trilhas
# Out:
# [{'estudantes': ['90729',
#    '113853',
#    '123736',
#    '129034',
#    '150878',
#    '151217',
#    '158257',
#    '159067',
#    '160836',
#    '160839',
#    '160852',
#    '160855',
#    '161223',
#    '161226',
#    '165431',
#    '165432',
#    '165685',
#    '165894',
#    '166050',
#    '171745',
#    '171749',
#    '172045',
#    '172207',
#    '172974',
#    '179944',
#    '11357',
#    '110307',
#    '118817',
#    '126813',
#    '147820',
#    '160841',
#    '160846',
#    '177170',
#    '190684',
#    '193634',
#    '198761',
#    '212903',
#    '250128',
#    '250152',
#    '251697',
#    '253829',
#    '253830'],
#   'trilhas': [['Fisica', 36],
#    ['Optativas Isoladas', 31],
#    ['IHC', 17],
#    ['Redes De Computadores', 5],
#    ['Otimizacao, Modelos Analiticos e de Simulacao', 4],
#    ['Processamento Grafico', 3],
#    ['Sistemas Inteligentes', 2],
#    ['Engenharia De Software', 2],
#    ['Banco De Dados', 2],
# ...

# %%
# os cliques são um pouco mais chatos de buscar, já que eles são uma lista de posição do vértice
print(cliques)
# passa como parâmetro a posição do vértice no grafo
def get_student_by_clique_pos(pos):
    return get_student_by_id(H.vs[pos]['_nx_name'])
# Out:
# [(69, 16, 19), (11, 75, 95), (124, 82, 129), (78, 97, 103), (3, 42, 119), (126, 7, 115, 32), (79, 43, 122, 81), (66, 6, 53, 47), (8, 28, 89, 42), (43, 56, 19, 24), (43, 56, 37, 25, 15), (43, 56, 37, 25, 24), (19, 1, 56, 24), (23, 1, 100, 91, 52), (97, 58, 94, 80, 68), (74, 5, 127, 76, 63, 17, 7), (48, 6, 107, 72, 64, 56, 53, 7), (7, 32, 45), (7, 32, 47), (7, 6, 53, 45), (7, 6, 53, 47), (7, 1, 47), (7, 1, 56), (80, 0, 68, 20), (80, 0, 68, 100, 91, 52, 1), (45, 6, 110, 108, 65, 62, 53, 46, 12), (137, 13, 114, 71, 70, 60, 59, 54, 51, 47, 41, 36, 32), (85, 0, 119, 112, 106, 84, 83, 61, 57, 38, 29, 22, 20, 2), (119, 0, 38, 42), (33, 0, 99, 50, 44, 42, 39, 38, 35, 34, 30, 27, 26, 24, 21), (38, 0, 99, 50, 44, 39, 35, 34, 30, 27, 26, 24, 21, 20), (42, 0, 99, 89, 50, 44, 39, 35, 34, 30, 28, 27, 26, 24, 21), (31, 0, 128, 99, 50, 44, 39, 35, 34, 30, 27, 26, 24, 21, 20, 18), (0, 1, 145, 131, 125, 111, 100, 99, 91, 89, 87, 56, 52, 50, 44, 39, 37, 35, 34, 30, 28, 27, 26, 25, 24, 21)]

# %%
# Lista de trilhas com suas disciplinas
trilhas_map = []
with open("../texts/trilhas.txt") as f:
    for line in f.readlines():
        trilhas_map.append(line.split("\n")[0].split(";"))

# Define uma estrutura de cliques que possui uma lista de ids (os alunos) e uma lista de trilhas (ordenada e com número de alunos)
cliques_trilhas = []
for clique in cliques:
    cliq = {"estudantes":[],
            "trilhas":[],
            "disciplinas":[]}
    em_trilha = []  
    all_dis = [] 
    n_estudantes = 0    
    for c in clique:
        e_id = get_student_by_clique_pos(c)[0]
        n_estudantes += 1
        cliq["estudantes"].append(e_id)
        e = [e for e in estudantes if e.id_anonimo == e_id][0]
        # Adiciona todas as disciplinas que fazem parte das trilhas do estudante dentro da lista de discplinas do clique
        for t in e.trilhas:
            trilha = [tri for tri in trilhas_map if tri[0] == t][0]
            for d in e.disciplinas:
                if (d in trilha):
                    all_dis.append(d)
    for trilha in trilhas_map:
        est_in_trilha = 0
        for c in clique:
            e_trilhas = get_student_by_clique_pos(c)[1]
            if (trilha[0] in e_trilhas):
                est_in_trilha += 1
        if (est_in_trilha > 0):
            em_trilha.append([trilha[0], est_in_trilha])
    cliq["trilhas"] = sorted(em_trilha, key=lambda t: t[1], reverse=True)
    n_apperances = len(all_dis)
    # a 1a posição da disciplina mostra o número total de optativas realizadas
    cliq["disciplinas"].append(n_apperances)
    for d in all_dis:
        if d != "-":
            n_times = all_dis.count(d)
            # disciplina seguido pelo n de alunos que a realizou no clique
            cliq["disciplinas"].append([d, n_times])
            # evita inserções repetidas no futuro
            for idx, item in enumerate(all_dis):
                if item == d:
                    all_dis[idx] = '-'
        
    cliques_trilhas.append(cliq)
cliques_trilhas
# Out:
# [{'estudantes': ['182856', '145077', '150887'],
#   'trilhas': [['Sistemas Inteligentes', 3],
#    ['Banco De Dados', 3],
#    ['Optativas Isoladas', 1]],
#   'disciplinas': [15,
#    ['CSI56', 1],
#    ['CSI53', 3],
#    ['CSB53', 1],
#    ['CSB41', 3],
#    ['CSI58', 1],
#    ['CSB51', 1],
#    ['CSI31', 1],
#    ['CSB54', 1],
#    ['ES70J', 1],
#    ['ES70N', 1],
#    ['ED70T', 1]]},
#  {'estudantes': ['131014', '186036', '137191'],
#   'trilhas': [['Processamento Grafico', 3],
#    ['Desenvolvimento Baseado em Plataformas Programacao', 3]],
#   'disciplinas': [13,
#    ['CSV40', 2],
#    ['CSV30', 3],
#    ['DI84D', 2],
#    ['CSM44', 2],
#    ['CSV52', 1],
#    ['CSM40', 2],
#    ['CSM41', 1]]},
#  {'estudantes': ['190502', '190615', '193637'],
#   'trilhas': [['Algoritmos E Complexidade', 3], ['Banco De Dados', 3]],
#   'disciplinas': [13,
#    ['CSA41', 3],
#    ['CSA42', 2],
#    ['CSB41', 2],
#    ['CSB53', 3],
#    ['CSA45', 2],
#    ['CSB51', 1]]},
# ...

# %%
# roda o script da predição de links, para arrumar os dados para a utilização dos algs
# %run "../comunidades_disciplinas/Predicao_de_links.ipynb"
# Out:
#        ID_ANONIMO      CR PERIODO_CURSO   INGRESSO  CODIGO   ANO  PERIODO_ANO NOTA  CH SITUACAOALUNO SEMESTRE
# 0           13236  0,6826            10 2007-12-07   IF68E  2012            1  8,2  60       Formado   2012.1
# 1           13236  0,6826            10 2007-12-07   IF35J  2007            2    7  60       Formado   2007.2
# 2           13236  0,6826            10 2007-12-07   MA33K  2007            2    0  60       Formado   2007.2
# 3           13236  0,6826            10 2007-12-07  F2D070  2007            2  8,8  75       Formado   2007.2
# 4           13236  0,6826            10 2007-12-07  E1D000  2007            2    0  30       Formado   2007.2
# ...           ...     ...           ...        ...     ...   ...          ...  ...  ..           ...      ...
# 50021      261036   0,695             2 2023-09-08  ICSF13  2023            2  6,6  90       Regular   2023.2
# ...

# %% [markdown]
# # Implementação da predição de links com dados de comunidade

# %%
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib import colormaps
import sys
from itertools import combinations
from datetime import datetime
import pandas as pd
import numpy as np
sys.path.append('../utils')
from mapa_estudantes import get_historico_completo, gerar_estudantes, get_disciplinas_matriz_844
import igraph as ig
import random

# Funções para dado um estudante e uma disciplina, 
# verificar qual o peso extra que deve ser adicionado na predição de links para tal
'''
    Primeiramente será verificado quais as disicplinas optativas que o aluno já fez.
    Tendo isso, iremos procurar qual a comunidade (ou clique) que possui as trilhas dessas disciplinas como majoritárias.
    Com a comunidade, iremos atribuir um peso para todas as disciplinas das trilhas de tal comunidade/clique.
    Cálculo do peso:
        Utilizando a porcentagem de alunos que finalizaram a trilha de cada disciplina. Inicialmente, todas as disciplinas de uma trilha terão o mesmo peso
        Depois, podemos verificar dentro de cada trilha, quais foram as disciplinas mais realizadas, diminuindo o peso de uma disciplina que aparece pouco
                                                                                                     ou até zerando de uma que não aparece.
        Caso a disciplina seja obrigatória, ele deve ser adicionada de qualquer maneira.
    No final, teremos uma estrutura que relaciona o estudante com o peso "extra" que foi calculado para cada disciplina optativa
'''

# Dado um Ra, cria o grafo do caminho completo do estuante
def create_full_student_graph(ra):
    # Cria um grafo do percurso completo do aluno
    # Aluno com todas as disciplinas
    G_aluno_curso = nx.Graph()
    disciplinas = df_844_curso["CODIGO"].unique()
    G_aluno_curso.add_nodes_from(disciplinas)

    # Exibir o número de disciplinas
    df_844_curso_aluno = df_844_curso[df_844_curso["ID_ANONIMO"] == ra]

    for data in df_844_curso_aluno.groupby(["ID_ANONIMO"]):
        dados_estudante = data[1]
        disciplinas = (
            dados_estudante.sort_values(by=["SEMESTRE"])
            .groupby(["CODIGO"])
            .agg({"SEMESTRE": "last"})
            .sort_values(by=["SEMESTRE"])
            .itertuples()
        )
        for disc1, disc2 in combinations(disciplinas, 2):
            if semestres_consecutivos(disc1.SEMESTRE, disc2.SEMESTRE):
                if G_aluno_curso.has_edge(disc1.Index, disc2.Index):
                    G_aluno_curso[disc1.Index][disc2.Index]["weight"] += 1
                else:
                    G_aluno_curso.add_edge(disc1.Index, disc2.Index, weight=1)

    return G_aluno_curso

# Dado um grafo e o nome de um vértice, remove todas as arestas desse vértice
# Usado para remover disciplinas específicas (como optativas para teste)
def remove_all_edges_from_node(g, node_name):
    edge_subset = [e for e in g.edges() if (e[0] == node_name or e[1] == node_name)]
    new_g = g.copy()
    new_g.remove_edges_from(edge_subset)
    return new_g

# Dado um grafo, remove todas as arestas de 20% dos nós de um grafo
# Não parece ser muito útil, com essa função os grafos perdem um pouco o sentido
def remove_random_nodes(g):
    # Remove as arestas de 20% dos vértices
    # É interessante pegar apenas vértices que tem pelo menos alguma aresta
    nodes_with_edges = [node for node in g.nodes() if g.degree[node] > 0]
    proportion_edges = 0.2
    node_subset = list(random.sample(
        list(nodes_with_edges), int(proportion_edges * len(nodes_with_edges))
    ))
    #print("Nodes removed: ", node_subset)
    # Cria uma cópia do grafo e remove as arestas
    new_g = g.copy()
    for node in node_subset:
        new_g = remove_all_edges_from_node(new_g, node)
    
    return new_g

# Dado um grafo de estudante, remove todas as arestas de todos menos 1 nó de optativa
# n_maintained é o número de disciplinas que devem ser mantidas no grafo para testes
# eng_comp_only é uma flag que indica se todo tipo de disciplina pode ser mantida, ou se apenas disciplinas de eng_comp
def maintain_one_opt_node(g, n_maintained=1, eng_comp_only=False):
    # Busca quais são os vértices de disciplinas optativas
    disciplinas = df_844_optativas["CODIGO"].unique()
    nodes_with_edges = [node for node in g.nodes() if g.degree[node] > 0]
    opt_nodes_with_edges = [node for node in disciplinas
                            if node in nodes_with_edges]
    random.shuffle(opt_nodes_with_edges)
    if (len(opt_nodes_with_edges) == 0):
        print("Sem disciplinas optativas já realizadas. Sem recomendações.")
        return []
    # mantém n_maintained disicplinas, logo retira n_maintained da lista de nós que serão removidos
    #print("ALL OPTS: ", opt_nodes_with_edges)
    for i in range(n_maintained):
        # Remove apenas disciplinas de Computação
        if eng_comp_only:
            for j in range(len(opt_nodes_with_edges)):
                if 'CS' in opt_nodes_with_edges[j] or 'EE' in opt_nodes_with_edges[j]:
                    opt_nodes_with_edges.pop(j)
                    break
        # Remove uma disciplina qualquer
        else :
            opt_nodes_with_edges.pop()
    #print("REMOVED OPTS: ", opt_nodes_with_edges)
    new_g = g.copy()
    for node in opt_nodes_with_edges:
        new_g = remove_all_edges_from_node(new_g, node)
    return new_g, opt_nodes_with_edges

# Dado uma disciplina, retorna uma lista de cliques nos quais ela pertence
def get_course_cliques(codigo):
    cs = []
    for clique in cliques_trilhas:
        for d in clique['disciplinas'][1:]:
            if codigo == d[0]:
                cs.append(clique)
                break
    
    return cs

# Dado uma lista de disciplinas, retorna a melhor comunidade para ela
def get_course_community(disciplinas):
    # vetor para guardar as comunidades junto com a quantidade de estudantes nas trilhas de interesse
    comunidades_count = []
    for c in comunidades_trilhas:
        count = 0
        for node in disciplinas:
            for t in c['trilhas']:
                for full_t in trilhas_map:
                    if full_t[0] == t[0]:
                        if node in full_t:
                            count += t[1]
        comunidades_count.append({"community": c, "count": count})
    best_c = comunidades_count[0]
    for c in comunidades_count:
        if c["count"] > best_c["count"]:
            best_c = c
    return best_c

# retorna as disciplinas resultantes como um único conjunto, levando em conta todos os cliques
def get_recommended_courses_all_cliques(e_cliques, opt_nodes_with_edges):
    all_rec_dis = []
    n_dis = 0
    # para buscar a recomendação divide a quantidade de vezes que uma disciplina apareceu em todos os cliques pela quantidade total de disciplinas
    # Conta o número total de disciplinas
    for clique in e_cliques:
        n_dis += clique['disciplinas'][0]
    # Adiciona todas as disicplinas em um vetor
    for clique in e_cliques:
        for d in clique['disciplinas'][1:]:
            if d[0] not in opt_nodes_with_edges:
                for i in range(d[1]):
                    all_rec_dis.append(d[0])
    # Pega o valor das disciplinas
    rec_dis = []
    for d in all_rec_dis:
        if d != '-':
            nd = all_rec_dis.count(d)
            rec_dis.append([d, 10*(nd/n_dis)])
            all_rec_dis[:] = [x if x != d else '-' for x in all_rec_dis]
    return rec_dis

# retorna as disciplinas resultantes 
def get_recommended_courses_cliques(e_cliques, opt_nodes_with_edges):
    rec_dis = []
    n_dis = 0
    # Para cada clique, divide a quantidade de vezes que uma disciplina apareceu nele pela quantidade total de disciplinas
    for clique in e_cliques:
        clique_rec_dis = []
        curr_clique_rec_dis = []
        n_dis = clique['disciplinas'][0]
        for d in clique['disciplinas'][1:]:
            if d[0] not in opt_nodes_with_edges:
                for i in range(d[1]):
                    clique_rec_dis.append(d[0])
        # calcula o valor de cada disciplina para esse clique
        for d in clique_rec_dis:
            if d != '-':
                nd = clique_rec_dis.count(d)
                curr_clique_rec_dis.append([d, nd/n_dis])
                clique_rec_dis[:] = [x if x != d else '-' for x in clique_rec_dis]
        rec_dis.append(curr_clique_rec_dis)
    return rec_dis

# Dado um grafo, retorna uma lista de disciplinas recomendadas com a sua probabilidade de ser realizada
# Utilizando dados dos cliques encontrados
def get_recommended_courses_from_cliques(g, join_cliques=True):
    # pega as disciplinas optativas existentes
    disciplinas = df_844_optativas["CODIGO"].unique()
    nodes_with_edges = [node for node in g.nodes() if g.degree[node] > 0]
    opt_nodes_with_edges = [node for node in disciplinas
                            if node in nodes_with_edges]
    # caso não tenham disciplinas optativas existentes, roda com base no interesse
    # TODO: no momento iremos apenas ignorar esse caso
    if (len(opt_nodes_with_edges) == 0):
        print("Sem disciplinas optativas já realizadas. Sem recomendações.")
        return []
    # Caso tenham disciplinas, busca os cliques de cada uma delas
    e_cliques = []
    for node in opt_nodes_with_edges:
        course_cliques = get_course_cliques(node)
        if (len(course_cliques) > 0):
            e_cliques.append(get_course_cliques(node))
    if len(e_cliques) == 0:
        return []
    if (join_cliques):
        return get_recommended_courses_all_cliques(e_cliques[0], opt_nodes_with_edges)
    else:
        return get_recommended_courses_cliques(e_cliques[0], opt_nodes_with_edges)
    
# Dado um grafo, retoruna uma lista de disciplinas recomendadas com a sua probabilidade de ser realizada
# Utilizando dados das comunidades encontradas
def get_recommended_courses_from_communities(g):
    # pega as disciplinas optativas existentes
    disciplinas = df_844_optativas["CODIGO"].unique()
    nodes_with_edges = [node for node in g.nodes() if g.degree[node] > 0]
    opt_nodes_with_edges = [node for node in disciplinas
                            if node in nodes_with_edges]
    # caso não tenham disciplinas optativas existentes, roda com base no interesse
    # TODO: no momento iremos apenas ignorar esse caso
    if (len(opt_nodes_with_edges) == 0):
        print("Sem disciplinas optativas já realizadas. Sem recomendações.")
        return []
    # Busca a comunidade em que o estudante se encaixa
    community = get_course_community(opt_nodes_with_edges)
    n_dis = 0
    all_dis_count = []
    for e in community['community']['estudantes']:
        ds = get_student_by_id(e)[2]
        for d in ds:
            all_dis_count.append(d)
            n_dis += 1
    # calcula o valor de cada disciplina
    rec_dis = []
    for d in all_dis_count:
        if d != '-':
            nd = all_dis_count.count(d)
            rec_dis.append([d, nd/n_dis])
            all_dis_count[:] = [x if x != d else '-' for x in all_dis_count]
    return rec_dis


# Dado uma lista de disciplinas optativas que um estudante fez e o resultado de uma recomendação
# Retorna os valores de precision and recall
def calc_precision_and_recall(opts, recom, k=-1):
    if (len(opts) == 0 or len(recom) == 0):
        return 0.0, 0.0
    # Result: os elementos que foram recomendados pelo algoritmo
    result = []
    for r in recom:
        result.append(r[0])
    # Relevant elements: os elementos relevantes para o resultado (as disciplinas que o estudante efetivamente pegou)
    relevant_elements = opts
    # True Positives intersecção entre o resultado e os elementos relevantes:
    if (k == -1):
        true_positives = list(set(result[0:k]) & set(relevant_elements))
    else:
        true_positives = list(set(result[0:k]) & set(relevant_elements))
    # Precision: número de verdadeiros positivos pelo número de valores recomendados
    precision = len(true_positives) / len(result)
    # Recall: número de verdadeiros positivos pelo número de valores nos recomendados
    recall = len(true_positives) / len(relevant_elements)
    return precision, recall

'''
# Auxiliar para calulcar o DGC 
def calc_DCG_value(rel_i, i):
    return (np.power(2, rel_i) - 1)/np.log2(i+1+1)

# Dado uma lista de disciplinas optativas que um estudante fez e o resultado de uma recomendação
# Retorna o valor da métrica de ranking NDCG
def calc_NDCG(opts, recom):
    # O problema é tratar isso como se fosse um ranking.
    # As disciplinas opts são o IDCG, que é o ranking ideal.
    # Vamos tratar como se todas as disciplinas realizadas tivessem relevância 1
    idcg_array = []
    for opt in opts:
        idcg_array.append([opt, 1.0])
    # Calcula o idcg
    idcg = 0
    for i, opt in enumerate(idcg_array):
        idcg += calc_DCG_value(opt[1], i)
    # As disciplinas recomendadas já vem ordenadas e com um peso de 0 a 1
    dcg = 0
    for i, opt in enumerate(recom):
        # TODO: verificar isso 
        # O que faz sentido é calcular apenas para as disciplinas que foram feitas pelo aluno
        # Não faz sentido comparar dois rankings com itens diferentes certo?
        # logo, só soma no dcg caso a disciplina esteja em opts
        if (opt[0] in opts):
            dcg += calc_DCG_value(opt[1], i)
    ndcg = dcg/idcg
    print("DCG:", dcg, ";   IDCG:", idcg, ";   NDCG: ", ndcg)
    return ndcg
'''
# Out:
# '\n# Auxiliar para calulcar o DGC \ndef calc_DCG_value(rel_i, i):\n    return (np.power(2, rel_i) - 1)/np.log2(i+1+1)\n\n# Dado uma lista de disciplinas optativas que um estudante fez e o resultado de uma recomendação\n# Retorna o valor da métrica de ranking NDCG\ndef calc_NDCG(opts, recom):\n    # O problema é tratar isso como se fosse um ranking.\n    # As disciplinas opts são o IDCG, que é o ranking ideal.\n    # Vamos tratar como se todas as disciplinas realizadas tivessem relevância 1\n    idcg_array = []\n    for opt in opts:\n        idcg_array.append([opt, 1.0])\n    # Calcula o idcg\n    idcg = 0\n    for i, opt in enumerate(idcg_array):\n        idcg += calc_DCG_value(opt[1], i)\n    # As disciplinas recomendadas já vem ordenadas e com um peso de 0 a 1\n    dcg = 0\n    for i, opt in enumerate(recom):\n        # TODO: verificar isso \n        # O que faz sentido é calcular apenas para as disciplinas que foram feitas pelo aluno\n        # Não faz sentido comparar dois rankin
# ...

# %%
'''
    Com a estrutura do aluno finalizada, podemos apenas buscar o peso extra de cada disciplina.
    A função depende dos vértices u, v e do aluno, para verificar se ele já fez alguma das duas disciplinas 
    E se a outra deve ser adicionada
'''
# Out:
# '\n    Com a estrutura do aluno finalizada, podemos apenas buscar o peso extra de cada disciplina.\n    A função depende dos vértices u, v e do aluno, para verificar se ele já fez alguma das duas disciplinas \n    E se a outra deve ser adicionada\n'

# %% [markdown]
# # Testes

# %%
# Jaccard
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import PrecisionRecallDisplay

# inicialmente seleciona um aluno
RA_Paulo = 202266
RA_Adriano = 202250
RA_Cesar = 202417
RA_Daniel = 202688
RA_Ribas = 202689
RA_Felipe = 160776
RA_Hadryan = 202696
RA_Ricky = 202701

RAs_formados = []

for e in estudantes:
    if e.status == "Formado" and int(e.ano_ingresso) >= 17:
        RAs_formados.append(e.id_anonimo)

RAs_formados
# Out:
# ['145077',
#  '150873',
#  '150878',
#  '150887',
#  '150892',
#  '151217',
#  '156158',
#  '179944',
#  '190493',
#  '190494',
#  '190495',
#  '190499',
#  '190508',
#  '190615',
#  '191284',
#  '198372',
#  '198543',
#  '202261']

# %% [markdown]
# ### Optativas mantidas = 1

# %%
precisions_1 = []
recalls_1 = []

# Para K = 1
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 1)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_cliques(partial_graph)   
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_1.append(pr[0])
    recalls_1.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_1)[::-1]
precisions_1 = np.array(precisions_1)[sorted_indices]
recalls_1 = np.array(recalls_1)[sorted_indices]
av_precision_1 = np.mean(precisions_1)
av_recall_1 = np.mean(recalls_1)

# %% [markdown]
# ### Optativas mantidas = 2

# %%
precisions_2 = []
recalls_2 = []

# Para K = 1
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 2)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_cliques(partial_graph)   
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_2.append(pr[0])
    recalls_2.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_2)[::-1]
precisions_2 = np.array(precisions_2)[sorted_indices]
recalls_2 = np.array(recalls_2)[sorted_indices]
av_precision_2 = np.mean(precisions_2)
av_recall_2 = np.mean(recalls_2)

# %% [markdown]
# ### Optativas mantidas = 3

# %%
precisions_3 = []
recalls_3 = []

# Para K = 1
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 3)
    if partial_graph == [] or removed_opts == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_cliques(partial_graph) 
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_3.append(pr[0])
    recalls_3.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_3)[::-1]
precisions_3 = np.array(precisions_3)[sorted_indices]
recalls_3 = np.array(recalls_3)[sorted_indices]
av_precision_3 = np.mean(precisions_3)
av_recall_3 = np.mean(recalls_3)

# %%
# plota a curva do precision and recall, para os 3 casos
print("Média precision/recall para 1 Optativa:", av_precision_1, av_recall_1)
print("Média precision/recall para 2 Optativas:", av_precision_2, av_recall_2)
print("Média precision/recall para 3 Optativas:", av_precision_3, av_recall_3)
fig, ax = plt.subplots()
display_1 = PrecisionRecallDisplay(precision=precisions_1, recall=recalls_1)
display_1.plot(ax=ax, name="1 Optativa", color="lime")
display_2 = PrecisionRecallDisplay(precision=precisions_2, recall=recalls_2)
display_2.plot(ax=ax, name="2 Optativas", color="red")
display_3 = PrecisionRecallDisplay(precision=precisions_3, recall=recalls_3)
display_3.plot(ax=ax, name="3 Optativas", color="cyan")
plt.legend(loc="upper left", fontsize="small")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()
# Out:
# Média precision/recall para 1 Optativa: 0.10137645571571338 0.8137566137566138
# Média precision/recall para 2 Optativas: 0.0708058600806297 0.9398148148148149
# Média precision/recall para 3 Optativas: 0.06277301295012204 0.9196078431372549

# %% [markdown]
# # Repetindo os testes, mas limitando para disciplinas do DAINF e do DAELN

# %%
precisions_1_engcomp = []
recalls_1_engcomp = []

# Para K = 1
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 1, True)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_cliques(partial_graph)  
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_1_engcomp.append(pr[0])
    recalls_1_engcomp.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_1_engcomp)[::-1]
precisions_1_engcomp = np.array(precisions_1_engcomp)[sorted_indices]
recalls_1_engcomp = np.array(recalls_1_engcomp)[sorted_indices]
av_precision_1_engcomp = np.mean(precisions_1_engcomp)
av_recall_1_engcomp = np.mean(recalls_1_engcomp)

# %%
precisions_2_engcomp = []
recalls_2_engcomp = []

# Para K = 2
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 2, True)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_cliques(partial_graph)  
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_2_engcomp.append(pr[0])
    recalls_2_engcomp.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_2_engcomp)[::-1]
precisions_2_engcomp = np.array(precisions_2_engcomp)[sorted_indices]
recalls_2_engcomp = np.array(recalls_2_engcomp)[sorted_indices]
av_precision_2_engcomp = np.mean(precisions_2_engcomp)
av_recall_2_engcomp = np.mean(recalls_2_engcomp)

# %%
precisions_3_engcomp = []
recalls_3_engcomp = []

# Para K = 3
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 3, True)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_cliques(partial_graph)  
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_3_engcomp.append(pr[0])
    recalls_3_engcomp.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_3_engcomp)[::-1]
precisions_3_engcomp = np.array(precisions_3_engcomp)[sorted_indices]
recalls_3_engcomp = np.array(recalls_3_engcomp)[sorted_indices]
av_precision_3_engcomp = np.mean(precisions_3_engcomp)
av_recall_3_engcomp = np.mean(recalls_3_engcomp)

# %%
# plota a curva do precision and recall, para os 3 casos
print("Média precision/recall para 1 Optativa (apenas engcomp):", av_precision_1_engcomp, av_recall_1_engcomp)
print("Média precision/recall para 2 Optativas (apenas engcomp):", av_precision_2_engcomp, av_recall_2_engcomp)
print("Média precision/recall para 3 Optativas (apenas engcomp):", av_precision_3_engcomp, av_recall_3_engcomp)
fig, ax = plt.subplots()
display_1_engcomp = PrecisionRecallDisplay(precision=precisions_1_engcomp, recall=recalls_1_engcomp)
display_1_engcomp.plot(ax=ax, name="1 Optativa (de EngComp)", color="darkgreen")
display_2_engcomp = PrecisionRecallDisplay(precision=precisions_2_engcomp, recall=recalls_2_engcomp)
display_2_engcomp.plot(ax=ax, name="2 Optativas (de EngComp)", color="maroon")
display_3_engcomp = PrecisionRecallDisplay(precision=precisions_3_engcomp, recall=recalls_3_engcomp)
display_3_engcomp.plot(ax=ax, name="3 Optativas (de EngComp)", color="darkblue")
plt.legend(loc="upper left", fontsize="small")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()
# Out:
# Média precision/recall para 1 Optativa (apenas engcomp): 0.09237382986657047 0.7800264550264551
# Média precision/recall para 2 Optativas (apenas engcomp): 0.08218463464230033 0.799074074074074
# Média precision/recall para 3 Optativas (apenas engcomp): 0.05658532179284628 0.8870370370370371

# %%
# Plota tudo junto
print("Média precision/recall para 1 Optativa:", av_precision_1, av_recall_1)
print("Média precision/recall para 2 Optativas:", av_precision_2, av_recall_2)
print("Média precision/recall para 3 Optativas:", av_precision_3, av_recall_3)
print("Média precision/recall para 1 Optativa (apenas engcomp):", av_precision_1_engcomp, av_recall_1_engcomp)
print("Média precision/recall para 2 Optativas (apenas engcomp):", av_precision_2_engcomp, av_recall_2_engcomp)
print("Média precision/recall para 3 Optativas (apenas engcomp):", av_precision_3_engcomp, av_recall_3_engcomp)
# plota a curva do precision and recall, para os 3 casos
fig, ax = plt.subplots()
display_1 = PrecisionRecallDisplay(precision=precisions_1, recall=recalls_1)
display_1.plot(ax=ax, name="1 Optativa", color="lime")
display_2 = PrecisionRecallDisplay(precision=precisions_2, recall=recalls_2)
display_2.plot(ax=ax, name="2 Optativas", color="red")
display_3 = PrecisionRecallDisplay(precision=precisions_3, recall=recalls_3)
display_3.plot(ax=ax, name="3 Optativas", color="cyan")
display_1_engcomp = PrecisionRecallDisplay(precision=precisions_1_engcomp, recall=recalls_1_engcomp)
display_1_engcomp.plot(ax=ax, name="1 Optativa (de EngComp)", color="darkgreen")
display_2_engcomp = PrecisionRecallDisplay(precision=precisions_2_engcomp, recall=recalls_2_engcomp)
display_2_engcomp.plot(ax=ax, name="2 Optativas (de EngComp)", color="maroon")
display_3_engcomp = PrecisionRecallDisplay(precision=precisions_3_engcomp, recall=recalls_3_engcomp)
display_3_engcomp.plot(ax=ax, name="3 Optativas (de EngComp)", color="darkblue")
plt.legend(loc="upper left", fontsize="small")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()
# Out:
# Média precision/recall para 1 Optativa: 0.10137645571571338 0.8137566137566138
# Média precision/recall para 2 Optativas: 0.0708058600806297 0.9398148148148149
# Média precision/recall para 3 Optativas: 0.06277301295012204 0.9196078431372549
# Média precision/recall para 1 Optativa (apenas engcomp): 0.09237382986657047 0.7800264550264551
# Média precision/recall para 2 Optativas (apenas engcomp): 0.08218463464230033 0.799074074074074
# Média precision/recall para 3 Optativas (apenas engcomp): 0.05658532179284628 0.8870370370370371

# %% [markdown]
# # Testes utilizando cliques separados

# %%
# Para K = 1
precisions_recalls = []
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 1, True)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_cliques(partial_graph, False)  
    print(rec_courses)
    # Calcula o precision/recall
    # vetor de vetores
    # Cada vetor é uma coleção de precision/recall para todos os cliques de um aluno
    # Logo, cada aluno terá um plot separado, e não um ponto
    prs = {'RA':ra, 'precisions': [], 'recalls': [], 'av_precision': 0, 'av_recall': 0}
    for rc in rec_courses:
        pr = calc_precision_and_recall(removed_opts, rc)
        prs['precisions'].append(pr[0])
        prs['recalls'].append(pr[1])
    prs['av_precision'] = np.mean(prs['precisions'])
    prs['av_recall'] = np.mean(prs['recalls'])
    precisions_recalls.append(prs)

# Plota tudo junto. Cada plot é para um aluno
fig, ax = plt.subplots()
for pr in precisions_recalls:
    print("RA: " + pr['RA'] + " Média precision/recall para 1 Optativa:", pr['av_precision'], pr['av_recall'])
    sorted_indices = np.argsort(pr['recalls'])[::-1]
    ps = np.array(pr['precisions'])[sorted_indices]
    rs = np.array(pr['recalls'])[sorted_indices]
    display = PrecisionRecallDisplay(precision=ps, recall=rs)
    display.plot(ax=ax, name=pr['RA'])
plt.legend(loc="upper left", fontsize="xx-small")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()
# Out:
# [[['CSI56', 0.06666666666666667], ['CSB53', 0.06666666666666667], ['CSB41', 0.2], ['CSI58', 0.06666666666666667], ['CSB51', 0.06666666666666667], ['CSI31', 0.06666666666666667], ['CSB54', 0.06666666666666667], ['ES70J', 0.06666666666666667], ['ES70N', 0.06666666666666667], ['ED70T', 0.06666666666666667]], [['CSI41', 0.13043478260869565], ['CSI57', 0.043478260869565216], ['CSH30', 0.17391304347826086], ['CSH42', 0.17391304347826086], ['CSV40', 0.043478260869565216], ['CSV30', 0.08695652173913043], ['CSV45', 0.043478260869565216], ['CSI56', 0.043478260869565216], ['CSR42', 0.043478260869565216], ['CSR44', 0.043478260869565216], ['CSR43', 0.043478260869565216]], [['CSV45', 0.03333333333333333], ['CSV30', 0.06666666666666667], ['CSB41', 0.06666666666666667], ['CSB51', 0.06666666666666667], ['GE70F', 0.1], ['ES70N', 0.13333333333333333], ['CSV40', 0.06666666666666667], ['CSI41', 0.03333333333333333], ['FI70D', 0.06666666666666667], ['FI70A', 0.06666666666666667], ['CSI31', 0.0333333333333
# ...

# %%
# Para K = 2
precisions_recalls = []
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 2, True)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_cliques(partial_graph, False)  
    # Calcula o precision/recall
    # vetor de vetores
    # Cada vetor é uma coleção de precision/recall para todos os cliques de um aluno
    # Logo, cada aluno terá um plot separado, e não um ponto
    prs = {'RA':ra, 'precisions': [], 'recalls': [], 'av_precision': 0, 'av_recall': 0}
    for rc in rec_courses:
        pr = calc_precision_and_recall(removed_opts, rc)
        prs['precisions'].append(pr[0])
        prs['recalls'].append(pr[1])
    prs['av_precision'] = np.mean(prs['precisions'])
    prs['av_recall'] = np.mean(prs['recalls'])
    precisions_recalls.append(prs)

# Plota tudo junto. Cada plot é para um aluno
fig, ax = plt.subplots()
for pr in precisions_recalls:
    print("RA: " + pr['RA'] + " Média precision/recall para 2 Optativas:", pr['av_precision'], pr['av_recall'])
    sorted_indices = np.argsort(pr['recalls'])[::-1]
    ps = np.array(pr['precisions'])[sorted_indices]
    rs = np.array(pr['recalls'])[sorted_indices]
    display = PrecisionRecallDisplay(precision=ps, recall=rs)
    display.plot(ax=ax, name=pr['RA'])
plt.legend(loc="upper left", fontsize="xx-small")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()
# Out:
# RA: 145077 Média precision/recall para 2 Optativas: 0.0732796451914099 0.2833333333333333
# RA: 150873 Média precision/recall para 2 Optativas: 0.11294938737964628 0.45588235294117646
# RA: 150878 Média precision/recall para 2 Optativas: 0.07636607856308668 0.3333333333333333
# RA: 150887 Média precision/recall para 2 Optativas: 0.15434999535876728 0.4222222222222222
# RA: 150892 Média precision/recall para 2 Optativas: 0.162090948503992 0.7166666666666668
# RA: 151217 Média precision/recall para 2 Optativas: 0.12173827634353948 0.27777777777777773
# RA: 156158 Média precision/recall para 2 Optativas: 0.08346748661150283 0.5
# RA: 179944 Média precision/recall para 2 Optativas: 0.15023753999474151 0.5428571428571428
# RA: 190493 Média precision/recall para 2 Optativas: 0.054639284863743066 0.23529411764705882
# RA: 190494 Média precision/recall para 2 Optativas: 0.07762960824341898 0.6153846153846154
# ...

# %%
# Para K = 3
precisions_recalls = []
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 3, True)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_cliques(partial_graph, False)
    # Calcula o precision/recall
    # vetor de vetores
    # Cada vetor é uma coleção de precision/recall para todos os cliques de um aluno
    # Logo, cada aluno terá um plot separado, e não um ponto
    prs = {'RA':ra, 'precisions': [], 'recalls': [], 'av_precision': 0, 'av_recall': 0}
    for rc in rec_courses:
        pr = calc_precision_and_recall(removed_opts, rc)
        prs['precisions'].append(pr[0])
        prs['recalls'].append(pr[1])
    prs['av_precision'] = np.mean(prs['precisions'])
    prs['av_recall'] = np.mean(prs['recalls'])
    precisions_recalls.append(prs)

# Plota tudo junto. Cada plot é para um aluno
fig, ax = plt.subplots()
for pr in precisions_recalls:
    print("RA: " + pr['RA'] + " Média precision/recall para 3 Optativas:", pr['av_precision'], pr['av_recall'])
    sorted_indices = np.argsort(pr['recalls'])[::-1]
    ps = np.array(pr['precisions'])[sorted_indices]
    rs = np.array(pr['recalls'])[sorted_indices]
    display = PrecisionRecallDisplay(precision=ps, recall=rs)
    display.plot(ax=ax, name=pr['RA'])
plt.legend(loc="upper left", fontsize="xx-small")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()
# Out:
# RA: 145077 Média precision/recall para 3 Optativas: 0.0732796451914099 0.3777777777777777
# RA: 150873 Média precision/recall para 3 Optativas: 0.09523628246538464 0.4259259259259259
# RA: 150878 Média precision/recall para 3 Optativas: 0.0616481974618164 0.3229166666666667
# RA: 150887 Média precision/recall para 3 Optativas: 0.12895468728802062 0.3888888888888889
# RA: 150892 Média precision/recall para 3 Optativas: 0.11075068279590534 0.5104166666666666
# RA: 151217 Média precision/recall para 3 Optativas: 0.11613756613756612 0.3111111111111111
# RA: 156158 Média precision/recall para 3 Optativas: 0.02454780407146136 0.20833333333333334
# RA: 179944 Média precision/recall para 3 Optativas: 0.09214435087269347 0.4642857142857143
# RA: 190493 Média precision/recall para 3 Optativas: 0.08088665147488677 0.4444444444444444
# RA: 190494 Média precision/recall para 3 Optativas: 0.05297292214948593 0.8461538461538461
# ...

# %% [markdown]
# # Testes utilizando comunidades

# %%
precisions_1 = []
recalls_1 = []

# Para K = 1
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 1)
    if partial_graph == [] or removed_opts == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_communities(partial_graph) 
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_1.append(pr[0])
    recalls_1.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_1)[::-1]
precisions_1 = np.array(precisions_1)[sorted_indices]
recalls_1 = np.array(recalls_1)[sorted_indices]
av_precision_1 = np.mean(precisions_1)
av_recall_1 = np.mean(recalls_1)

# %%
precisions_2 = []
recalls_2 = []

# Para K = 1
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 2)
    if partial_graph == [] or removed_opts == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_communities(partial_graph) 
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_2.append(pr[0])
    recalls_2.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_2)[::-1]
precisions_2 = np.array(precisions_2)[sorted_indices]
recalls_2 = np.array(recalls_2)[sorted_indices]
av_precision_2 = np.mean(precisions_2)
av_recall_2 = np.mean(recalls_2)

# %%
precisions_3 = []
recalls_3 = []

# Para K = 1
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 3)
    if partial_graph == [] or removed_opts == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_communities(partial_graph) 
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_3.append(pr[0])
    recalls_3.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_3)[::-1]
precisions_3 = np.array(precisions_3)[sorted_indices]
recalls_3 = np.array(recalls_3)[sorted_indices]
av_precision_3 = np.mean(precisions_3)
av_recall_3 = np.mean(recalls_3)

# %%
# plota a curva do precision and recall, para os 3 casos
print("Média precision/recall para 1 Optativa:", av_precision_1, av_recall_1)
print("Média precision/recall para 2 Optativas:", av_precision_2, av_recall_2)
print("Média precision/recall para 3 Optativas:", av_precision_3, av_recall_3)
fig, ax = plt.subplots()
display_1 = PrecisionRecallDisplay(precision=precisions_1, recall=recalls_1)
display_1.plot(ax=ax, name="1 Optativa", color="lime")
display_2 = PrecisionRecallDisplay(precision=precisions_2, recall=recalls_2)
display_2.plot(ax=ax, name="2 Optativas", color="red")
display_3 = PrecisionRecallDisplay(precision=precisions_3, recall=recalls_3)
display_3.plot(ax=ax, name="3 Optativas", color="cyan")
plt.legend(loc="upper left", fontsize="small")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()
# Out:
# Média precision/recall para 1 Optativa: 0.10264793561305191 0.9174603174603173
# Média precision/recall para 2 Optativas: 0.08019161716836136 0.9157407407407407
# Média precision/recall para 3 Optativas: 0.06212888115076898 0.8774509803921569

# %%
precisions_1_engcomp = []
recalls_1_engcomp = []

# Para K = 1
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 1, True)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_communities(partial_graph)  
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_1_engcomp.append(pr[0])
    recalls_1_engcomp.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_1_engcomp)[::-1]
precisions_1_engcomp = np.array(precisions_1_engcomp)[sorted_indices]
recalls_1_engcomp = np.array(recalls_1_engcomp)[sorted_indices]
av_precision_1_engcomp = np.mean(precisions_1_engcomp)
av_recall_1_engcomp = np.mean(recalls_1_engcomp)

# %%
precisions_2_engcomp = []
recalls_2_engcomp = []

# Para K = 1
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 2, True)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_communities(partial_graph)  
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_2_engcomp.append(pr[0])
    recalls_2_engcomp.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_2_engcomp)[::-1]
precisions_2_engcomp = np.array(precisions_2_engcomp)[sorted_indices]
recalls_2_engcomp = np.array(recalls_2_engcomp)[sorted_indices]
av_precision_2_engcomp = np.mean(precisions_2_engcomp)
av_recall_2_engcomp = np.mean(recalls_2_engcomp)

# %%
precisions_3_engcomp = []
recalls_3_engcomp = []

# Para K = 1
for ra in RAs_formados:
    # cria o grafo
    full_graph = create_full_student_graph(int(ra))
    # retira todas menos uma optativa
    # removed_opts será utilizada para calcular os valores ideais
    partial_graph, removed_opts = maintain_one_opt_node(full_graph, 3, True)
    if partial_graph == []:
        continue
    # busca as disciplinas recomendadas
    rec_courses = get_recommended_courses_from_communities(partial_graph)  
    # Calcula o precision/recall
    pr = calc_precision_and_recall(removed_opts, rec_courses)
    precisions_3_engcomp.append(pr[0])
    recalls_3_engcomp.append(pr[1])

# Ordena precision/recall na ordem crescente dos recalls
sorted_indices = np.argsort(recalls_3_engcomp)[::-1]
precisions_3_engcomp = np.array(precisions_3_engcomp)[sorted_indices]
recalls_3_engcomp = np.array(recalls_3_engcomp)[sorted_indices]
av_precision_3_engcomp = np.mean(precisions_3_engcomp)
av_recall_3_engcomp = np.mean(recalls_3_engcomp)

# %%
# plota a curva do precision and recall, para os 3 casos
print("Média precision/recall para 1 Optativa (apenas engcomp):", av_precision_1_engcomp, av_recall_1_engcomp)
print("Média precision/recall para 2 Optativas (apenas engcomp):", av_precision_2_engcomp, av_recall_2_engcomp)
print("Média precision/recall para 3 Optativas (apenas engcomp):", av_precision_3_engcomp, av_recall_3_engcomp)
fig, ax = plt.subplots()
display_1_engcomp = PrecisionRecallDisplay(precision=precisions_1_engcomp, recall=recalls_1_engcomp)
display_1_engcomp.plot(ax=ax, name="1 Optativa (de EngComp)", color="darkgreen")
display_2_engcomp = PrecisionRecallDisplay(precision=precisions_2_engcomp, recall=recalls_2_engcomp)
display_2_engcomp.plot(ax=ax, name="2 Optativas (de EngComp)", color="maroon")
display_3_engcomp = PrecisionRecallDisplay(precision=precisions_3_engcomp, recall=recalls_3_engcomp)
display_3_engcomp.plot(ax=ax, name="3 Optativas (de EngComp)", color="darkblue")
plt.legend(loc="upper left", fontsize="small")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()

# %%
# Plota tudo junto
print("Média precision/recall para 1 Optativa:", av_precision_1, av_recall_1)
print("Média precision/recall para 2 Optativas:", av_precision_2, av_recall_2)
print("Média precision/recall para 3 Optativas:", av_precision_3, av_recall_3)
print("Média precision/recall para 1 Optativa (apenas engcomp):", av_precision_1_engcomp, av_recall_1_engcomp)
print("Média precision/recall para 2 Optativas (apenas engcomp):", av_precision_2_engcomp, av_recall_2_engcomp)
print("Média precision/recall para 3 Optativas (apenas engcomp):", av_precision_3_engcomp, av_recall_3_engcomp)
# plota a curva do precision and recall, para os 3 casos
fig, ax = plt.subplots()
display_1 = PrecisionRecallDisplay(precision=precisions_1, recall=recalls_1)
display_1.plot(ax=ax, name="1 Optativa", color="lime")
display_2 = PrecisionRecallDisplay(precision=precisions_2, recall=recalls_2)
display_2.plot(ax=ax, name="2 Optativas", color="red")
display_3 = PrecisionRecallDisplay(precision=precisions_3, recall=recalls_3)
display_3.plot(ax=ax, name="3 Optativas", color="cyan")
display_1_engcomp = PrecisionRecallDisplay(precision=precisions_1_engcomp, recall=recalls_1_engcomp)
display_1_engcomp.plot(ax=ax, name="1 Optativa (de EngComp)", color="darkgreen")
display_2_engcomp = PrecisionRecallDisplay(precision=precisions_2_engcomp, recall=recalls_2_engcomp)
display_2_engcomp.plot(ax=ax, name="2 Optativas (de EngComp)", color="maroon")
display_3_engcomp = PrecisionRecallDisplay(precision=precisions_3_engcomp, recall=recalls_3_engcomp)
display_3_engcomp.plot(ax=ax, name="3 Optativas (de EngComp)", color="darkblue")
plt.legend(loc="upper left", fontsize="small")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()
