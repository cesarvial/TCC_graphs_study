# %% [markdown]
# ### NetworkX e Gephi
# Use o código abaixo em conjunto com o Gephi:
# 1. carregue o exemplo Les Miserables.gexf no Gephi
# 2. exporte no formato GML (miserables.gml) para carregar no notebook
#
# Esta rede representa as interações dos personagens do romance de Victor Hugo.\
# Compare alguns valores fornecidos pelo NetworkX com os disponíveis no Gephi

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()

# disciplinas 
with open("disciplinas.txt") as file:
    for line in file:
        G.add_node(line.rstrip())
G.nodes()
# Out:
# NodeView(('P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'CSS30', 'CSF13', 'CSD20', 'MA71A', 'FI71S', 'MA71B', 'EEX11', 'CSF20', 'CSE20', 'CSX53', 'MA72A', 'FI72S', 'FI72N', 'QB70C', 'EEX21', 'CSF30', 'MA70H', 'MA73A', 'FI73S', 'EEB21', 'MA70G', 'CSD21', 'EEB22', 'EEB31', 'EEF11', 'EEQ31', 'FI74N', 'FI74S', 'CSA30', 'CSB30', 'CSG20', 'CSR31', 'CSW30', 'EEE31', 'EEF21', 'ES70G', 'CSA31', 'CSE30', 'CSO30', 'CSW40', 'EEE32', 'EEX22', 'CSI30', 'CSR30', 'CSW41', 'CSW42', 'EEC21', 'EEQ32', 'ES70P', 'EEC31', 'EEX23', 'GE70D', 'CSX42', 'GE70H', 'QB70E', 'CSX43', 'EEF31', 'CSA40', 'CSA41', 'CSA42', 'CSA43', 'CSA44', 'CSA45', 'CSB40', 'CSB41', 'CSB42', 'CSB43', 'CSB50', 'CSB51', 'CSB52', 'CSB53', 'CSX54', 'CSB54', 'CSB55', 'CSD40', 'CSD41', 'CSD42', 'CSD43', 'CSD45', 'CSD47', 'CSD52', 'CSD55', 'CSD57', 'CSD58', 'CSE40', 'CSE41', 'CSE42', 'CSE43', 'CSE44', 'CSE45', 'CSE46', 'CSE47', 'CSE48', 'CSG41', 'CSG42', 'CSG43', 'CSG44', 'CSG45', 'CSG47', 'CSG48', 'CSG70', 'CSH30', 'CSH41', 'CSH42', 'CSH43', 'CSH44', 'CSH45', 'CSH50', 'CSH51', 'CSI31', 'CSI41', 'CSI42', 'CSI51', 'CSI52', 'CSI53', 'CSI54', 'CSI55', 'CSI56', 'CSI57', 'CSI58', 'CSL40', 'CSL41', 'CSM30', 'CSM40', 'CSM41', 'CSM42', 'CSM43', 'CSM44', 'CSM45', 'CSR20', 'CSR40', 'CSR41', 'CSR42', 'CSR43', 'CSR44', 'CSR45', 'CSR46', 'CSR47', 'CSR48', 'CSR53', 'CSU40', 'CSU41', 'CSU42', 'CSU43', 'CSU44', 'CSV30', 'CSV40', 'CSV41', 'CSV42', 'CSV43', 'CSV45', 'CSV50', 'CSV52', 'CSV53', 'CSW43', 'CSW44', 'CSW45', 'CSW46', 'CSW47', 'CSW48', 'CSW49', 'CSW55', 'CSW56', 'DI84D', 'ED70T', 'ED70U', 'EEC41', 'EEC42', 'EEC43', 'EEC44', 'EEC45', 'EEC46', 'EEL51', 'EES41', 'EEY41', 'EEY42', 'EEY43', 'EEY44', 'EEY51', 'EEY52', 'ELH03', 'ELSC01', 'ELSP01', 'EL6AE', 'EL6BA', 'EL6BB', 'EL6BC', 'EL6BD', 'EL6BE', 'EL6CA', 'EL6CB', 'EL6CC', 'EL6CD', 'EL6EE', 'EL64B', 'EL65B', 'EL65F', 'EL66B', 'EL75H', 'ES70B', 'ES70J', 'ES70N', 'ET7GL', 'ET7GM', 'FCH7FC', 'FCH7GA', 'FCH7HB', 'FCH7HC', 'FCH7SC', 'FCH7XF', 'FCH7XG', 'FI70A', 'FI70B', 'FI70D', 'FI70E', 'FI77B', 'GE70F', 'ICSB55', 'IF6BV', 'IF6CJ', 'IF6CK', 'IF6CM', 'LEM701', 'LEM702', 'LEM703', 'MA7AV', 'MA70C', 'QB7AH', 'QB7AI', 'QB70F', 'QB74I'))

# %%
print(G.number_of_nodes())
# Out:
# 241

# %%
# todas as dependencias entre disciplinas
with open("dependencias.txt") as file:
    for line in file:
        G.add_edge(line.rstrip().split(";")[0], line.rstrip().split(";")[1])
G.edges()
# Out:
# EdgeView([('P1', 'CSF13'), ('P1', 'CSD20'), ('P1', 'MA71A'), ('P1', 'FI71S'), ('P1', 'MA71B'), ('P2', 'CSF13'), ('P2', 'CSD20'), ('P2', 'MA71A'), ('P2', 'FI71S'), ('P2', 'MA71B'), ('P2', 'CSF20'), ('P2', 'CSE20'), ('P2', 'MA72A'), ('P2', 'FI72S'), ('P2', 'FI72N'), ('P2', 'QB70C'), ('P2', 'EEX11'), ('P2', 'CSX53'), ('P3', 'CSX53'), ('P3', 'CSF20'), ('P3', 'CSE20'), ('P3', 'MA72A'), ('P3', 'FI72S'), ('P3', 'FI72N'), ('P3', 'QB70C'), ('P3', 'EEX11'), ('P3', 'CSF30'), ('P3', 'MA70H'), ('P3', 'MA73A'), ('P3', 'FI73S'), ('P3', 'EEB21'), ('P3', 'MA70G'), ('P3', 'EEX21'), ('P3', 'CSU42'), ('P4', 'CSF30'), ('P4', 'MA70H'), ('P4', 'MA73A'), ('P4', 'FI73S'), ('P4', 'EEB21'), ('P4', 'MA70G'), ('P4', 'EEX21'), ('P4', 'EEF11'), ('P4', 'CSD21'), ('P4', 'EEB22'), ('P4', 'EEB31'), ('P4', 'EEQ31'), ('P4', 'FI74N'), ('P4', 'FI74S'), ('P5', 'EEF11'), ('P5', 'CSD21'), ('P5', 'EEB22'), ('P5', 'EEB31'), ('P5', 'EEQ31'), ('P5', 'FI74N'), ('P5', 'FI74S'), ('P5', 'CSA30'), ('P5', 'CSB30'), ('P5', 'CSG20'), ('P5', 'CSR31'), ('P5', 'CSW30'), ('P5', 'EEE31'), ('P5', 'EEF21'), ('P5', 'ES70G'), ('P5', 'ELSP01'), ('P6', 'CSA30'), ('P6', 'CSB30'), ('P6', 'CSG20'), ('P6', 'C
P8', 'CSU44'), ('P8', 'CSV30'), ('P8', 'CSV40'), ('P8', 'CSV41'), ('P8', 'CSV42'), ('P8', 'CSV43'), ('P8', 'CSV45'), ('P8', 'CSV50'), ('P8', 'CSV52'), ('P8', 'CSV53'), ('P8', 'CSW43'), ('P8', 'CSW44'), ('P8', 'CSW45'), ('P8', 'CSW46'), ('P8', 'CSW47'), ('P8', 'CSW48'), ('P8', 'CSW49'), ('P8', 'CSW55'), ('P8', 'ED70U'), ('P8', 'EEC41'), ('P8', 'EEC42'), ('P8', 'EEC43'), ('P8', 'EEC44'), ('P8', 'EEC45'), ('P8', 'EEC46'), ('P8', 'EEL51'), ('P8', 'EES41'), ('P8', 'EEY41'), ('P8', 'EEY42'), ('P8', 'EEY43'), ('P8', 'EEY44'), ('P8', 'EEY51'), ('P8', 'EEY52'), ('P8', 'EL6AE'), ('P8', 'EL6BA'), ('P8', 'EL6BB'), ('P8', 'EL6BC'), ('P8', 'EL6BD'), ('P8', 'EL6BE'), ('P8', 'EL6CA'), ('P8', 'EL6CD'), ('P8', 'EL64B'), ('P8', 'EL65B'), ('P8', 'EL65F'), ('P8', 'EL66B'), ('P8', 'EL75H'), ('P8', 'ES70B'), ('P8', 'FI70A'), ('P8', 'FI70B'), ('P8', 'FI70D'), ('P8', 'FI70E'), ('P8', 'FI77B'), ('P8', 'IF ...

# %%
print(G.number_of_edges())
# Out:
# 287

# %%
nx.draw(G, with_labels=True, arrows=True, node_size=50, font_size=5)

# %%
G.degree()
# Out:
# DegreeView({'P1': 5, 'P2': 13, 'P3': 16, 'P4': 14, 'P5': 16, 'P6': 18, 'P7': 15, 'P8': 178, 'P9': 7, 'P10': 5, 'CSS30': 2, 'CSF13': 2, 'CSD20': 2, 'MA71A': 2, 'FI71S': 2, 'MA71B': 2, 'EEX11': 2, 'CSF20': 2, 'CSE20': 2, 'CSX53': 2, 'MA72A': 2, 'FI72S': 2, 'FI72N': 2, 'QB70C': 2, 'EEX21': 2, 'CSF30': 2, 'MA70H': 2, 'MA73A': 2, 'FI73S': 2, 'EEB21': 2, 'MA70G': 2, 'CSD21': 2, 'EEB22': 2, 'EEB31': 2, 'EEF11': 2, 'EEQ31': 2, 'FI74N': 2, 'FI74S': 2, 'CSA30': 2, 'CSB30': 2, 'CSG20': 2, 'CSR31': 2, 'CSW30': 2, 'EEE31': 2, 'EEF21': 2, 'ES70G': 2, 'CSA31': 2, 'CSE30': 2, 'CSO30': 2, 'CSW40': 2, 'EEE32': 2, 'EEX22': 2, 'CSI30': 2, 'CSR30': 2, 'CSW41': 2, 'CSW42': 2, 'EEC21': 2, 'EEQ32': 2, 'ES70P': 2, 'EEC31': 2, 'EEX23': 2, 'GE70D': 2, 'CSX42': 2, 'GE70H': 2, 'QB70E': 2, 'CSX43': 1, 'EEF31': 1, 'CSA40': 1, 'CSA41': 1, 'CSA42': 1, 'CSA43': 1, 'CSA44': 1, 'CSA45': 1,
F': 1, 'FCH7XG': 1, 'FI70A': 1, 'FI70B': 1, 'FI70D': 1, 'FI70E': 1, 'FI77B': 1, 'GE70F': 1, 'ICSB55': 1, 'IF6BV': 1, 'IF6CJ': 1, 'IF6CK': 1, 'IF6CM': 1, 'LEM701': 1, 'LEM702': 1, 'LEM703': 1, 'MA7AV': 1, 'MA70C': 1, 'QB7AH': 1, 'QB7AI': 1, 'QB70F': 1, 'QB74I': 1})

# %%
dicDegree = dict(G.degree() )
valores = sorted(set(dicDegree.values()))
valores

hist = [list(dicDegree.values()).count(x) for x in valores]

plt.plot(valores, hist, 'ro-') 

plt.xlabel('Grau')
plt.ylabel('Numero de nós')
# Out:
# Text(0, 0.5, 'Numero de nós')

# %%
deg=dict(G.degree())
soma = 0
for i in deg.values():
    soma += i
aver = soma/len(deg)
print(aver)
print(nx.average_clustering(G))
print(nx.average_clustering(G, count_zeros=False))
print(nx.diameter(G))
#print(nx.clustering(G))
clus=dict(nx.clustering(G))

# Gephi: average clustering coefficient for nodes with degree > 1 ()
soma = 0
c = 0
for i in range(len(deg)):
    if list(deg.values())[i] > 1:
     soma += list(clus.values())[i]
     c +=1
clus_aver = soma/c;
print(clus_aver)
# Out:
# 2.3817427385892116
# 0.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\Users\cesar\TCC\grafo_periodos\grafo_periodos.ipynb Cell 9 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/cesar/TCC/grafo_periodos/grafo_periodos.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> print(aver)
#       <a href='vscode-notebook-cell:/c%3A/Users/cesar/TCC/grafo_periodos/grafo_periodos.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> print(nx.average_clustering(G))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cesar/TCC/grafo_periodos/grafo_periodos.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> print(nx.average_clustering(G, count_zeros=False))
#       <a href='vscode-notebook-cell:/c%3A/Users/cesar/TCC/grafo_periodos/grafo_periodos.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> print(nx.diameter(G))
#      <a href='vscode-notebook-cell:/c%3A/Users/cesar/TCC/grafo_periodos/grafo_periodos.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a> #print(nx.clustering(G))
#
# File c:\Users\cesar\AppData\Local\Programs\Python\Python310\lib\site-packages\networkx\classes\backends.py:148, in _dispatch.<locals>.wrapper(*args, **kwds)
#     144         else:
#     145             raise NetworkXNotImplemented(
#     146                 f"'{name}' not implemented by {plugin_name}"
#     147             )
# --> 148 return func(*args, **kwds)
#
# File c:\Users\cesar\AppData\Local\Programs\Python\Python310\lib\site-packages\networkx\algorithms\cluster.py:280, in average_clustering(G, nodes, weight, count_zeros)
#     278 if not count_zeros:
#     279     c = [v for v in c if abs(v) > 0]
# --> 280 return sum(c) / len(c)
#
# ZeroDivisionError: division by zero

# %%
nx.write_gexf(G, "grafo_periodos.gexf")
